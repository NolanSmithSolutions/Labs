# %% [markdown]
# ### Instructions:
# Ensure the chromedriver app is in the same folder as this notebook
#
# ---------------

# %%
# Run this cell first

import selenium
from bs4 import *
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.keys import Keys
import time
import getpass
import requests

# %% [markdown]
# 1. Create a function that will open and return a headless web browser, think of variables that may be helpful to send the function.

# %% [markdown]
# 2. Go to: https://www.macrotrends.net/1333/historical-gold-prices-100-year-chart and scrape the table titled 'Gold Prices - Historical Annual Data'

# %% [markdown]
# 3.  Put the data from question 2 in a pandas dataframe.

# %% [markdown]
# 4. Get the latest bloomberg news topic.

# %% [markdown]
# 5. Go to https://www.basketball-reference.com/leagues/NBA_2022_leaders.html and scrape the top 20 players in rebounds per game for the last 25 years along with their rebounds per game and the year that it occured.  Wait 4 seconds after each year of data scraped.

# %% [markdown]
# 6. Put the data from question 5 into a pandas dataframe, print out any players that have been in this dataset more than once and the count of how many times that player has been in there.  Then display the dataframe, sorted by rebounds per game.

# %% [markdown]
# 7. Create a user input for username and password, where password is hidden as it is typed.  Run the cell asking for this with sample inputs and print out the password afterwords.  What problem do you notice?
